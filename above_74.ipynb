# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style(style="whitegrid")

# %%
df_gols = pd.read_csv('camp-bras-gols-a-74.csv')

# %%
df_gols.columns

# %%
gpr = df_gols[['rodada']].value_counts(ascending=True).sort_index(ascending=True)
gpr.plot(kind='bar')

# %%
sns.displot(gpr,kde=True)

# %%
a74 = recorte.sort_index(ascending=True)

# %%
#a74.to_csv('gols-a-74.csv')

# %%
a74.plot(kind='barh')
