# %%
import pandas as pd

# %%
df_gols = pd.read_csv('camp-bras-gols-a-74.csv')

# %%
df_gols.columns
# Out:
# Index(['partida_id', 'rodada', 'clube', 'atleta', 'minuto', 'tipo_de_gol'], dtype='object')

# %%
df_gols = pd.DataFrame(df_gols)

# %%
df_gols

# %%
recorte = df_gols[["minuto"]]

# %%
recorte
# Out:
#       minuto
# 0         80
# 1         80
# 2         83
# 3         75
# 4         78
# ...      ...
# 1730      80
# 1731      92
# 1732      96
# 1733      96
# 1734      82
#
# [1735 rows x 1 columns]

# %%
recorte.plot(kind='bar')
# Out:
# <Axes: >

# %%
df_gols['minuto'].sort_values(ascending=True)

# %%
df_gols['minuto'].plot(kind='bar')
